# %%
# %sql
CREATE CATALOG IF NOT EXISTS FMCG;
USE CATALOG FMCG;

# %%
# %sql
-- Silver and bronze schemas are exclusively for child company (sportsbar) whereas gold schema will eventually contain data from both parent and child company
CREATE SCHEMA IF NOT EXISTS FMCG.gold;
CREATE SCHEMA IF NOT EXISTS FMCG.silver;
CREATE SCHEMA IF NOT EXISTS FMCG.bronze;
